# %% [markdown]
# ### <center> xo-wa</center>

# %% [markdown]
# ```
# nvm use 16.17.0
# pip install wa-automate-socket-client
#
# cd session_folder
# npx @open-wa/wa-automate -v --multi-device --socket -p 8085 -k xo --qr-timeout 0 --license-key 6826E910-BC034D2F-97A755C0-AC7A0C86
# ```

# %%
from xo import *
# from openwa import WhatsAPIDriver
# from selenium import webdriver
# from munch import Munch
import os
import re
import time

# import json
# import requests
# from resizeimage import resizeimage
# import magic
# from PIL import Image
# from base64 import b64decode, b64encode
# from c18core import *

# chromedriverV = 89
# chromedriverV = 98

from wa_automate_socket_client import SocketClient


def initClient(firstTime=False):
    client = SocketClient("http://localhost:8085/", "xo")
    if not firstTime:
        client.onMessage(lambda data,*a,**kw: print("!!!!INCOMING!!!!",xo.incoming._setValue((data,a,kw))))
    else:
        found = False
        while not found:
            try:
                res = client.getHostNumber()
                if res != "":
                    found = True
                    print("@@@@@@@@@@@@@@ CONNECTED TO WA", res)
                    client.sendText("972547932000@c.us",
                                    "!!!!! WA SERVER LIVE !!!!!\n"+res)
                    # client.onMessage(lambda data,*a,**kw: print("!!!!INCOMING!!!!",xo.incoming._setValue((data,a,kw))))
                    client.onMessage(lambda data: print("!!!!INCOMING!!!!",xo.incoming(data)))
            except:
                print(".... wa hasnt loaded yet")
                time.sleep(1)

        client.getHostNumber()
    return client


# print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@ starting wa")
# xo.cmd("sh /root/startWa.sh")
# print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
client = initClient(True)
# client..
# Out:
# @@@@@@@@@@@@@@ CONNECTED TO WA 972547932000

# %%
def handleSendMessage(number, msg):
    number = number + "@c.us" if "@c.us" not in number and "@g.us" not in number else number
    number = number.replace("+", "")
    return client.sendText(number, msg)
    # return True
    links = re.findall(r'\b((?:https?://)?(?:(?:www\.)?(?:[\da-z\.-]+)\.(?:[a-z]{2,6})|(?:(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)\.){3}(?:25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)|(?:(?:[0-9a-fA-F]{1,4}:){7,7}[0-9a-fA-F]{1,4}|(?:[0-9a-fA-F]{1,4}:){1,7}:|(?:[0-9a-fA-F]{1,4}:){1,6}:[0-9a-fA-F]{1,4}|(?:[0-9a-fA-F]{1,4}:){1,5}(?::[0-9a-fA-F]{1,4}){1,2}|(?:[0-9a-fA-F]{1,4}:){1,4}(?::[0-9a-fA-F]{1,4}){1,3}|(?:[0-9a-fA-F]{1,4}:){1,3}(?::[0-9a-fA-F]{1,4}){1,4}|(?:[0-9a-fA-F]{1,4}:){1,2}(?::[0-9a-fA-F]{1,4}){1,5}|[0-9a-fA-F]{1,4}:(?:(?::[0-9a-fA-F]{1,4}){1,6})|:(?:(?::[0-9a-fA-F]{1,4}){1,7}|:)|fe80:(?::[0-9a-fA-F]{0,4}){0,4}%[0-9a-zA-Z]{1,}|::(?:ffff(?::0{1,4}){0,1}:){0,1}(?:(?:25[0-5]|(?:2[0-4]|1{0,1}[0-9]){0,1}[0-9])\.){3,3}(?:25[0-5]|(?:2[0-4]|1{0,1}[0-9]){0,1}[0-9])|(?:[0-9a-fA-F]{1,4}:){1,4}:(?:(?:25[0-5]|(?:2[0-4]|1{0,1}[0-9]){0,1}[0-9])\.){3,3}(?:25[0-5]|(?:2[0-4]|1{0,1}[0-9]){0,1}[0-9])))(?::[0-9]{1,4}|[1-5][0-9]{4}|6[0-4][0-9]{3}|65[0-4][0-9]{2}|655[0-2][0-9]|6553[0-5])?(?:/[\w\.-]*)*/?)\b', msg)
    if links and len(links) > 0:
        print(links)
        print(f"Sending preview with link: {links[0]}")
        try:
            # response, res = sendMessageUrlPost(number, msg, links[0])
            res = client.sendLinkWithAutoPreview(number, links[0], msg)
        except:
            print("After exception: sending regular message without preview")
            res = client.sendText(number, msg)
    else:
        print("Sending regular message without preview")
        res = client.sendText(number, msg)
    print("DONE sending")
    # return response, res
    print(res)
    return res


def sendMessageQuick(number="972547932000@c.us", msg="Yo"):
    global client
    try:
        return handleSendMessage(number, msg)
    except:
        client = initClient()
        return handleSendMessage(number, msg)


##########################
sendMessageQuick("972547932000@c.us", "Hello")

xo.wa.msg = lambda number="972547932000@c.us", msg="Yo": sendMessageQuick(number, msg)
xo.wa.send = xo.wa.msg

xo.wa = lambda number,msg: xo.wa.msg(number,msg)
# xo.wa.msg(msg = "alright")
xo.wa@("972547932000","alright!!!!!!!!!!!!!!!!")  # type: ignore
# Out:
# @@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@   matmul  @@@@@@@
# @@@@@@@@     x     @@@@@@@
# @@@@@@@@     x     @@@@@@@
# @@@@@@@@           @@@@@@@ <class 'tuple'>
# @@@@@@@@@@@@@@@@@@@@@@@@@@ ('972547932000', 'alright!!!!!!!!!!!!!!!!')
# 'true_972547932000@c.us_3EB0589869B3DEB5C9CD_out'

# %%
xo.wa.incoming @= lambda msg: print(" ::: incoming message: ", msg)
print(xo.wa.send("972547932000","hi mom!"))  # type: ignore
# Out:
#  ::: Subscribing to incoming
# true_972547932000@c.us_3EB01F92154A95680332_out

# %%
xo.msg = "hi mom!"
xo.msg.extra = "love"
xo.msg.sender = "son"
# print(xo.wa.send("972547932000","hi mom!"))  # type: ignore
print(xo.wa.send("972547932000",str(xo.msg)))  # type: ignore
# del xo.msg
# Out:
# true_972547932000@c.us_3EB06A190ADBBA2C1737_out

# %% [markdown]
# <center>auto issues report</center>
#
# ```

# %%
xo.issue @= lambda data : print(xo.wa.send(xo.master(),
f'''
*Reporting Issue:*
{data}
'''))
xo.master = "972547932000"
# xo.issue("reporting issue")
xo.issue = "reporting issue"
print(xo)
# Out:
#  ::: Subscribing to issue
# true_972547932000@c.us_3EB020A7844876230C84_out
# {'wa': {'msg': <function <lambda> at 0x7f0032d38550>, 'send': <function <lambda> at 0x7f0032d38550>, 'value': <function <lambda> at 0x7f003433be50>, 'incoming': {}}, 'msg': {'value': 'hi mom!', 'extra': 'love', 'sender': 'son'}, 'issue': 'reporting issue', 'master': '972547932000'}

# %%
# xo.issue = "YYYYYYYYOOOOOOO"
def mockRobee(robee):
    # robee._setValue = "robee1"
    robee._setValue("robee1")
    robee.sw.server.version = "1.0.0"
    robee.sw.server.version = "1.0.0"
    robee.hw.vescs.version = "1.0.0"
    robee.hw.motor.id = "ToyotaXR7"
    robee.hw.motor.version = "a1"
    robee.hw.sensors.cameras = True
    robee.hw.sensors.gps = True
    robee.location = "Elad"
    robee.location.gps = "31.123, 34.123"
    robee.owner = "Elad"
    robee.created = "2022-08-31"


mockRobee(xo.field.robee1)
desc = "The motor is acting irregularly, please check it out. Thanks!"
xo.issue = f'''
{desc}

{dict(xo.field.robee1)}
'''
# Out:
# robee1
# true_972547932000@c.us_3EB0E66B1BD6D3DE0404_out

# %%
xo.issue = "ido is super awesome!"
# Out:
# true_972547932000@c.us_3EB05619508FADBD9642_out

# %%
def incomingMsgsFunction(data):
    global client
    data = data['data']
    # xo.indata = data
    l = lambda *a, **d: xo.pnr([f"Got MSG! me:{data['fromMe']}", data["chatId"], data["sender"]['id'], data["content"]])
    # messagegroup = data
    print()
    print("$$$$$$$$$$$$$$$$$$$$$$$$$$$$$ incoming")
    print(data)
    print("$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")
    content = data["content"]
    chatID = data["chatId"]
    if "$$$" in content:
        try:
            print("ECHO!!!!!!",content)
            client.sendText(chatID,"$$$ECHO:\n"+content)
        except:
            client = initClient()
            time.sleep(1)
            print("ECHO!!!!!!",content)
            client.sendText(chatID,"$$$ECHO:\n"+content)

    sender = data["sender"]['id']
    fulldata = data
    fromMe = data["fromMe"]
    phone = sender.split("@")[0]
    print("XXXX@@@@@@",content,chatID,sender,fromMe,phone)
    if fromMe:
        print("!!!!!!!!!! FROM ME")
    # else:
    #     # Checks if group is connected to a challenge
    #     waData = database.waGroups.find_one({"_id": chatID})
    #     if waData is not None:
    #         print(waData)
    #         rateEmoji(waData, phone, content)
    #         return xo.pnr(f"FUCK YEA! Recieved a msg from a challenge ::: {waData}\n ::: {sender} ::: {content} ")
    #     else:
    #         print("!!!!!!! GOT MESSAGE BUT NOT FROM A CHALLENGE")
    # xo.incomingData._setValue(data)
    xo.incomingData = data
    xo.incomingData.body = content
    xo.incomingData.chatID = chatID
    xo.incomingData.sender = sender

    return l()

# %%
xo.incoming = lambda data, *args, **kwargs: xo.incomingData._setValue((data,args,kwargs))
# xo.incoming = lambda data: incomingMsgsFunction(data)

xo.incomingData @= lambda data: print(" ::: INCOMING WHATSAPP MESSAGE :::", data,"\n\n\n\n") # type: ignore
# Out:
#  ::: Subscribing to incomingData

# %%
while True:
    time.sleep(1)
# Out:
#  ::: INCOMING WHATSAPP MESSAGE ::: ({'ts': 1662038913818, 'sessionId': 'session', 'id': '37e29020-b193-49eb-88b1-67cb3e503546', 'event': 'onMessage', 'data': {'id': 'false_972528750477@c.us_23168814EA038EE1153BE8146332A3CC', 'body': '', 'type': 'ptt', 't': 1662038913, 'notifyName': 'M', 'from': '972528750477@c.us', 'to': '972547932000@c.us', 'self': 'in', 'ack': 1, 'isNewMsg': True, 'star': False, 'kicNotified': False, 'recvFresh': True, 'clientUrl': 'https://mmg.whatsapp.net/d/f/AlRxr7WK2-bkXyXQnL_HVs4_K-V3Jjkoyo0cc2UkKYFP.enc', 'deprecatedMms3Url': 'https://mmg.whatsapp.net/d/f/AlRxr7WK2-bkXyXQnL_HVs4_K-V3Jjkoyo0cc2UkKYFP.enc', 'directPath': '/v/t62.7117-24/31852942_136635445744932_170502365878274243_n.enc?ccb=11-4&oh=01_AVyHTRCDGn2lCRvBvaMvchGSsg8hq4m1PYqI--Bz_oqZdA&oe=633678AF', 'mimetype': 'audio/ogg; codecs=opus', 'duration': '3', 'filehash': '1kgC/NQEjm93lfq7w0AQqqiyk4yYtEfvw4npb7hu0eA=', 'encFilehash': 'HXnS8EbgO2OzgRx5584YVTYisJM2BH9trUjWSkiYMRg=', 'size': 9093, 'mediaKey': 'E3RFV9lFS0sHjoDpj6Y5G2QhoDanM4WbQ3O1ILZr0Nc=', 'mediaKeyTimestamp': 1662038910, 'waveform': {'0': 0, '1': 0, '2': 5, '3': 27, '4': 38, '5': 42, '6': 36, '7': 21, '8': 24, '9': 46, '10': 51, '11': 48, '12': 48, '13': 51, '14': 52, '15': 43, '16': 45, '17': 22, '18': 28, '19': 40, '20': 29, '21': 2, '22': 0, '23': 6, '24': 19, '25': 27, '26': 22, '27': 42, '28': 37, '29': 44, '30': 55, '31': 58, '32': 21, '33': 41, '34': 49, '35': 18, '36': 33, '37': 44, '38': 42, '39': 36, '40': 21, '41': 8, '42': 32, '43': 23, '44': 22, '45': 19, '46': 12, '47': 21, '48': 34, '49': 40, '50': 41, '51': 45, '52': 36, '53': 40, '54': 30, '55': 19, '56': 23, '57': 34, '58': 43, '59': 53, '60': 48, '61': 24, '62': 18, '63': 25}, 'isFromTemplate': False, 'pollInvalidated': False, 'broadcast': False, 'quotedMsg': None, 'mentionedJidList': [], 'isVcardOverMmsDocument': False, 'isForwarded': False, 'labels': [], 'hasReaction': False, 'ephemeralOutOfSync': False, 'productHeaderImageRejected': False, 'lastPlaybackProgress': 0, 'isDynamicReplyButtonsMsg': False, 'isMdHistoryMsg': False, 'requiresDirectConnection': False, 'pttForwardedFeaturesEnabled': True, 'fromMe': False, 'mId': '23168814EA038EE1153BE8146332A3CC', 'sender': {'id': '972528750477@c.us', 'name': 'מאווי בכייף שלך ❤️', 'shortName': 'מאווי בכייף', 'pushname': 'M', 'type': 'in', 'isContactSyncCompleted': 1, 'formattedName': 'מאווי בכייף שלך ❤️', 'isMe': False, 'isMyContact': True, 'isPSA': False, 'isUser': True, 'isWAContact': True, 'profilePicThumbObj': {'eurl': None, 'id': '972528750477@c.us', 'tag': None}, 'msgs': None}, 'timestamp': 1662038913, 'isGroupMsg': False, 'isMedia': False, 'isNotification': False, 'isPSA': False, 'chat': {'id': '972528750477@c.us', 'lastReceivedKey': {'fromMe': True, 'remote': '972528750477@c.us', 'id': '6FB7C899EECDD21282EDEC31C8E0684A', '_serialized': 'true_972528750477@c.us_6FB7C899EECDD21282EDEC31C8E0684A'}, 't': 1662036320, 'unreadCount': 0, 'isReadOnly': False, 'muteExpiration': 0, 'notSpam': True, 'ephemeralDuration': 0, 'disappearingModeInitiator': 'chat', 'unreadMentionCount': 0, 'hasUnreadMention': False, 'archiveAtMentionViewedInDrawer': False, 'hasChatBeenOpened': False, 'tcToken': {}, 'tcTokenTimestamp': 1661780004, 'tcTokenSenderTimestamp': 1661678724, 'endOfHistoryTransferType': 2, 'pendingInitialLoading': False, 'msgs': None, 'kind': 'chat', 'canSend': True, 'isGroup': False, 'formattedTitle': 'מאווי בכייף שלך ❤️', 'contact': {'id': '972528750477@c.us', 'name': 'מאווי בכייף שלך ❤️', 'shortName': 'מאווי בכייף', 'pushname': 'M', 'type': 'in', 'isContactSyncCompleted': 1, 'formattedName': 'מאווי בכייף שלך ❤️', 'isMe': False, 'isMyContact': True, 'isPSA': False, 'isUser': True, 'isWAContact': True, 'profilePicThumbObj': {'eurl': None, 'id': '972528750477@c.us', 'tag': None}, 'msgs': None}, 'groupMetadata': None, 'presence': {'id': '972528750477@c.us', 'chatstates': []}, 'isOnline': False, 'participantsCount': 1}, 'isOnline': False, 'chatId': '972528750477@c.us', 'quotedMs ...
#
#
#
#
# ({'ts': 1662038913818, 'sessionId': 'session', 'id': '37e29020-b193-49eb-88b1-67cb3e503546', 'event': 'onMessage', 'data': {'id': 'false_972528750477@c.us_23168814EA038EE1153BE8146332A3CC', 'body': '', 'type': 'ptt', 't': 1662038913, 'notifyName': 'M', 'from': '972528750477@c.us', 'to': '972547932000@c.us', 'self': 'in', 'ack': 1, 'isNewMsg': True, 'star': False, 'kicNotified': False, 'recvFresh': True, 'clientUrl': 'https://mmg.whatsapp.net/d/f/AlRxr7WK2-bkXyXQnL_HVs4_K-V3Jjkoyo0cc2UkKYFP.enc', 'deprecatedMms3Url': 'https://mmg.whatsapp.net/d/f/AlRxr7WK2-bkXyXQnL_HVs4_K-V3Jjkoyo0cc2UkKYFP.enc', 'directPath': '/v/t62.7117-24/31852942_136635445744932_170502365878274243_n.enc?ccb=11-4&oh=01_AVyHTRCDGn2lCRvBvaMvchGSsg8hq4m1PYqI--Bz_oqZdA&oe=633678AF', 'mimetype': 'audio/ogg; codecs=opus', 'duration': '3', 'filehash': '1kgC/NQEjm93lfq7w0AQqqiyk4yYtEfvw4npb7hu0eA=', 'encFilehash': 'HXnS8EbgO2OzgRx5584YVTYisJM2BH9trUjWSkiYMRg=', 'size': 9093, 'mediaKey': 'E3RFV9lFS0sHjoDpj6Y5G2QhoDanM4WbQ3O1ILZr0Nc=', 'mediaKeyTimestamp': 1662038910, 'waveform': {'0': 0, '1': 0, '2': 5, '3': 27, '4': 38, '5': 42, '6': 36, '7': 21, '8': 24, '9': 46, '10': 51, '11': 48, '12': 48, '13': 51, '14': 52, '15': 43, '16': 45, '17': 22, '18': 28, '19': 40, '20': 29, '21': 2, '22': 0, '23': 6, '24': 19, '25': 27, '26': 22, '27': 42, '28': 37, '29': 44, '30': 55, '31': 58, '32': 21, '33': 41, '34': 49, '35': 18, '36': 33, '37': 44, '38': 42, '39': 36, '40': 21, '41': 8, '42': 32, '43': 23, '44': 22, '45': 19, '46': 12, '47': 21, '48': 34, '49': 40, '50': 41, '51': 45, '52': 36, '53': 40, '54': 30, '55': 19, '56': 23, '57': 34, '58': 43, '59': 53, '60': 48, '61': 24, '62': 18, '63': 25}, 'isFromTemplate': False, 'pollInvalidated': False, 'broadcast': False, 'quotedMsg': None, 'mentionedJidList': [], 'isVcardOverMmsDocument': False, 'isForwarded': False, 'labels': [], 'hasReaction': False, 'ephemeralOutOfSync': False, 'productHeaderImageRejected': False, 'lastPlaybackProgress': 0, 'isDynamicReplyButtonsMsg': False, 'isMdHistoryMsg': False, 'requiresDirectConnection': False, 'pttForwardedFeaturesEnabled': True, 'fromMe': False, 'mId': '23168814EA038EE1153BE8146332A3CC', 'sender': {'id': '972528750477@c.us', 'name': 'מאווי בכייף שלך ❤️', 'shortName': 'מאווי בכייף', 'pushname': 'M', 'type': 'in', 'isContactSyncCompleted': 1, 'formattedName': 'מאווי בכייף שלך ❤️', 'isMe': False, 'isMyContact': True, 'isPSA': False, 'isUser': True, 'isWAContact': True, 'profilePicThumbObj': {'eurl': None, 'id': '972528750477@c.us', 'tag': None}, 'msgs': None}, 'timestamp': 1662038913, 'isGroupMsg': False, 'isMedia': False, 'isNotification': False, 'isPSA': False, 'chat': {'id': '972528750477@c.us', 'lastReceivedKey': {'fromMe': True, 'remote': '972528750477@c.us', 'id': '6FB7C899EECDD21282EDEC31C8E0684A', '_serialized': 'true_972528750477@c.us_6FB7C899EECDD21282EDEC31C8E0684A'}, 't': 1662036320, 'unreadCount': 0, 'isReadOnly': False, 'muteExpiration': 0, 'notSpam': True, 'ephemeralDuration': 0, 'disappearingModeInitiator': 'chat', 'unreadMentionCount': 0, 'hasUnreadMention': False, 'archiveAtMentionViewedInDrawer': False, 'hasChatBeenOpened': False, 'tcToken': {}, 'tcTokenTimestamp': 1661780004, 'tcTokenSenderTimestamp': 1661678724, 'endOfHistoryTransferType': 2, 'pendingInitialLoading': False, 'msgs': None, 'kind': 'chat', 'canSend': True, 'isGroup': False, 'formattedTitle': 'מאווי בכייף שלך ❤️', 'contact': {'id': '972528750477@c.us', 'name': 'מאווי בכייף שלך ❤️', 'shortName': 'מאווי בכייף', 'pushname': 'M', 'type': 'in', 'isContactSyncCompleted': 1, 'formattedName': 'מאווי בכייף שלך ❤️', 'isMe': False, 'isMyContact': True, 'isPSA': False, 'isUser': True, 'isWAContact': True, 'profilePicThumbObj': {'eurl': None, 'id': '972528750477@c.us', 'tag': None}, 'msgs': None}, 'groupMetadata': None, 'presence': {'id': '972528750477@c.us', 'chatstates': []}, 'isOnline': False, 'participantsCount': 1}, 'isOnline': False, 'chatId': '972528750477@c.us', 'quotedMsgObj': None, 'mediaData': {'type':  ...
# !!!!INCOMING!!!! None
#  ::: INCOMING WHATSAPP MESSAGE ::: ({'ts': 1662039549062, 'sessionId': 'session', 'id': '1a8e3894-7f17-45a2-b4f2-bcdd8a3b9e24', 'event': 'onMessage', 'data': {'id': 'false_120363023352246358@g.us_5F982E14D23F582550AE4B4DFFD51B33_972525577999@c.us', 'body': 'חח\nולמה את צריכה להיות מנהלת בקבוצה.?', 'type': 'chat', 't': 1662039548, 'notifyName': '⚜️David Rom, Cyber Shield⚜️', 'from': '120363023352246358@g.us', 'to': '972547932000@c.us', 'author': '972525577999@c.us', 'self': 'in', 'ack': 1, 'isNewMsg': True, 'star': False, 'kicNotified': False, 'recvFresh': True, 'isFromTemplate': False, 'pollInvalidated': False, 'broadcast': False, 'quotedMsg': None, 'mentionedJidList': [], 'isVcardOverMmsDocument': False, 'isForwarded': False, 'labels': [], 'hasReaction': False, 'productHeaderImageRejected': False, 'lastPlaybackProgress': 0, 'isDynamicReplyButtonsMsg': False, 'isMdHistoryMsg': False, 'requiresDirectConnection': False, 'pttForwardedFeaturesEnabled': True, 'fromMe': False, 'mId': '5F982E14D23F582550AE4B4DFFD51B33', 'sender': {'id': '972525577999@c.us', 'pushname': '⚜️David Rom, Cyber Shield⚜️', 'type': 'in', 'isContactSyncCompleted': 1, 'formattedName': '+972 52-557-7999', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': True, 'isWAContact': True, 'profilePicThumbObj': {}, 'msgs': None}, 'timestamp': 1662039548, 'content': 'חח\nולמה את צריכה להיות מנהלת בקבוצה.?', 'isGroupMsg': True, 'isMedia': False, 'isNotification': False, 'isPSA': False, 'chat': {'id': '120363023352246358@g.us', 'lastReceivedKey': {'fromMe': False, 'remote': '120363023352246358@g.us', 'id': 'B690326B03733323FFAD9EDE68A87CA4', 'participant': '972508674222@c.us', '_serialized': 'false_120363023352246358@g.us_B690326B03733323FFAD9EDE68A87CA4_972508674222@c.us'}, 't': 1662036663, 'unreadCount': 1400, 'archive': True, 'isReadOnly': False, 'isAnnounceGrpRestrict': False, 'muteExpiration': 0, 'name': 'בוטי - עזרה,תמיכה,קהילה82', 'notSpam': True, 'ephemeralDuration': 0, 'unreadMentionsOfMe': [], 'unreadMentionCount': 0, 'hasUnreadMention': False, 'archiveAtMentionViewedInDrawer': False, 'hasChatBeenOpened': False, 'tcToken': None, 'tcTokenTimestamp': None, 'endOfHistoryTransferType': 2, 'pendingInitialLoading': False, 'msgs': None, 'kind': 'group', 'canSend': True, 'isGroup': True, 'formattedTitle': 'בוטי - עזרה,תמיכה,קהילה82', 'contact': {'id': '120363023352246358@g.us', 'name': 'בוטי - עזרה,תמיכה,קהילה82', 'type': 'in', 'formattedName': 'בוטי - עזרה,תמיכה,קהילה82', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': False, 'isWAContact': False, 'profilePicThumbObj': {'id': '120363023352246358@g.us', 'img': None, 'imgFull': None}, 'msgs': None}, 'groupMetadata': {'id': '120363023352246358@g.us', 'creation': 1644362711, 'owner': '972523737233@c.us', 'subject': 'בוטי - עזרה,תמיכה,קהילה82', 'subjectTime': 1644362711, 'desc': 'הקבוצה סגורה בשבתות תפתח אחרי שבת. \nרוצים לדעת מה קרה לבוטי?\nאיך אפשר להשתמש עכשיו?\nולמה זה קשור לפייסבוק?\nקראו כאן:    https://boti.bot/SwRI2ygd785H', 'descId': '5226FF95474EDA7DF44DD47523DE3C6E', 'descTime': 1644590663, 'descOwner': '972523737233@c.us', 'restrict': True, 'announce': False, 'noFrequentlyForwarded': False, 'ephemeralDuration': 0, 'size': 172, 'support': False, 'suspended': False, 'terminated': False, 'uniqueShortNameMap': {}, 'isParentGroup': False, 'defaultSubgroup': False, 'lastActivityTimestamp': 0, 'lastSeenActivityTimestamp': 0, 'incognito': False, 'participants': [{'id': '972523737233@c.us', 'isAdmin': True, 'isSuperAdmin': True}, {'id': '97249529911@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502036117@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502044103@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502272246@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502313231@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502740111@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502818065@c.us', 'isAdmin': False, 'isSuper ...
#
#
#
#
# ({'ts': 1662039549062, 'sessionId': 'session', 'id': '1a8e3894-7f17-45a2-b4f2-bcdd8a3b9e24', 'event': 'onMessage', 'data': {'id': 'false_120363023352246358@g.us_5F982E14D23F582550AE4B4DFFD51B33_972525577999@c.us', 'body': 'חח\nולמה את צריכה להיות מנהלת בקבוצה.?', 'type': 'chat', 't': 1662039548, 'notifyName': '⚜️David Rom, Cyber Shield⚜️', 'from': '120363023352246358@g.us', 'to': '972547932000@c.us', 'author': '972525577999@c.us', 'self': 'in', 'ack': 1, 'isNewMsg': True, 'star': False, 'kicNotified': False, 'recvFresh': True, 'isFromTemplate': False, 'pollInvalidated': False, 'broadcast': False, 'quotedMsg': None, 'mentionedJidList': [], 'isVcardOverMmsDocument': False, 'isForwarded': False, 'labels': [], 'hasReaction': False, 'productHeaderImageRejected': False, 'lastPlaybackProgress': 0, 'isDynamicReplyButtonsMsg': False, 'isMdHistoryMsg': False, 'requiresDirectConnection': False, 'pttForwardedFeaturesEnabled': True, 'fromMe': False, 'mId': '5F982E14D23F582550AE4B4DFFD51B33', 'sender': {'id': '972525577999@c.us', 'pushname': '⚜️David Rom, Cyber Shield⚜️', 'type': 'in', 'isContactSyncCompleted': 1, 'formattedName': '+972 52-557-7999', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': True, 'isWAContact': True, 'profilePicThumbObj': {}, 'msgs': None}, 'timestamp': 1662039548, 'content': 'חח\nולמה את צריכה להיות מנהלת בקבוצה.?', 'isGroupMsg': True, 'isMedia': False, 'isNotification': False, 'isPSA': False, 'chat': {'id': '120363023352246358@g.us', 'lastReceivedKey': {'fromMe': False, 'remote': '120363023352246358@g.us', 'id': 'B690326B03733323FFAD9EDE68A87CA4', 'participant': '972508674222@c.us', '_serialized': 'false_120363023352246358@g.us_B690326B03733323FFAD9EDE68A87CA4_972508674222@c.us'}, 't': 1662036663, 'unreadCount': 1400, 'archive': True, 'isReadOnly': False, 'isAnnounceGrpRestrict': False, 'muteExpiration': 0, 'name': 'בוטי - עזרה,תמיכה,קהילה82', 'notSpam': True, 'ephemeralDuration': 0, 'unreadMentionsOfMe': [], 'unreadMentionCount': 0, 'hasUnreadMention': False, 'archiveAtMentionViewedInDrawer': False, 'hasChatBeenOpened': False, 'tcToken': None, 'tcTokenTimestamp': None, 'endOfHistoryTransferType': 2, 'pendingInitialLoading': False, 'msgs': None, 'kind': 'group', 'canSend': True, 'isGroup': True, 'formattedTitle': 'בוטי - עזרה,תמיכה,קהילה82', 'contact': {'id': '120363023352246358@g.us', 'name': 'בוטי - עזרה,תמיכה,קהילה82', 'type': 'in', 'formattedName': 'בוטי - עזרה,תמיכה,קהילה82', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': False, 'isWAContact': False, 'profilePicThumbObj': {'id': '120363023352246358@g.us', 'img': None, 'imgFull': None}, 'msgs': None}, 'groupMetadata': {'id': '120363023352246358@g.us', 'creation': 1644362711, 'owner': '972523737233@c.us', 'subject': 'בוטי - עזרה,תמיכה,קהילה82', 'subjectTime': 1644362711, 'desc': 'הקבוצה סגורה בשבתות תפתח אחרי שבת. \nרוצים לדעת מה קרה לבוטי?\nאיך אפשר להשתמש עכשיו?\nולמה זה קשור לפייסבוק?\nקראו כאן:    https://boti.bot/SwRI2ygd785H', 'descId': '5226FF95474EDA7DF44DD47523DE3C6E', 'descTime': 1644590663, 'descOwner': '972523737233@c.us', 'restrict': True, 'announce': False, 'noFrequentlyForwarded': False, 'ephemeralDuration': 0, 'size': 172, 'support': False, 'suspended': False, 'terminated': False, 'uniqueShortNameMap': {}, 'isParentGroup': False, 'defaultSubgroup': False, 'lastActivityTimestamp': 0, 'lastSeenActivityTimestamp': 0, 'incognito': False, 'participants': [{'id': '972523737233@c.us', 'isAdmin': True, 'isSuperAdmin': True}, {'id': '97249529911@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502036117@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502044103@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502272246@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502313231@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502740111@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502818065@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '97250288551 ...
# !!!!INCOMING!!!! None
#  ::: INCOMING WHATSAPP MESSAGE ::: ({'ts': 1662040661527, 'sessionId': 'session', 'id': '612d0569-9c18-4655-866f-a06c28569fdd', 'event': 'onMessage', 'data': {'id': 'false_120363023352246358@g.us_1A42EA78BE581585A8B67324672740D1_972509500753@c.us', 'body': '', 'type': 'ciphertext', 't': 1662040661, 'notifyName': 'sigalsason1234', 'from': '120363023352246358@g.us', 'to': '972547932000@c.us', 'author': '972509500753@c.us', 'self': 'in', 'ack': 1, 'isNewMsg': True, 'star': False, 'kicNotified': False, 'recvFresh': True, 'isFromTemplate': False, 'pollInvalidated': False, 'broadcast': False, 'quotedMsg': None, 'mentionedJidList': [], 'isVcardOverMmsDocument': False, 'isForwarded': False, 'labels': [], 'hasReaction': False, 'productHeaderImageRejected': False, 'lastPlaybackProgress': 0, 'isDynamicReplyButtonsMsg': False, 'isMdHistoryMsg': False, 'requiresDirectConnection': False, 'pttForwardedFeaturesEnabled': True, 'fromMe': False, 'mId': '1A42EA78BE581585A8B67324672740D1', 'sender': {'id': '972509500753@c.us', 'type': 'in', 'formattedName': '+972 50-950-0753', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': True, 'isWAContact': True, 'profilePicThumbObj': {}, 'msgs': None}, 'timestamp': 1662040661, 'isGroupMsg': True, 'isMedia': False, 'isNotification': False, 'isPSA': False, 'chat': {'id': '120363023352246358@g.us', 'lastReceivedKey': {'fromMe': False, 'remote': '120363023352246358@g.us', 'id': '3EB0D76D7B4AC09F9CCC', 'participant': '972509500753@c.us', '_serialized': 'false_120363023352246358@g.us_3EB0D76D7B4AC09F9CCC_972509500753@c.us'}, 't': 1662039548, 'unreadCount': 1401, 'archive': True, 'isReadOnly': False, 'isAnnounceGrpRestrict': False, 'muteExpiration': 0, 'name': 'בוטי - עזרה,תמיכה,קהילה82', 'notSpam': True, 'ephemeralDuration': 0, 'unreadMentionsOfMe': [], 'unreadMentionCount': 0, 'hasUnreadMention': False, 'archiveAtMentionViewedInDrawer': False, 'hasChatBeenOpened': False, 'tcToken': None, 'tcTokenTimestamp': None, 'endOfHistoryTransferType': 2, 'pendingInitialLoading': False, 'msgs': None, 'kind': 'group', 'canSend': True, 'isGroup': True, 'formattedTitle': 'בוטי - עזרה,תמיכה,קהילה82', 'contact': {'id': '120363023352246358@g.us', 'name': 'בוטי - עזרה,תמיכה,קהילה82', 'type': 'in', 'formattedName': 'בוטי - עזרה,תמיכה,קהילה82', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': False, 'isWAContact': False, 'profilePicThumbObj': {'id': '120363023352246358@g.us', 'img': None, 'imgFull': None}, 'msgs': None}, 'groupMetadata': {'id': '120363023352246358@g.us', 'creation': 1644362711, 'owner': '972523737233@c.us', 'subject': 'בוטי - עזרה,תמיכה,קהילה82', 'subjectTime': 1644362711, 'desc': 'הקבוצה סגורה בשבתות תפתח אחרי שבת. \nרוצים לדעת מה קרה לבוטי?\nאיך אפשר להשתמש עכשיו?\nולמה זה קשור לפייסבוק?\nקראו כאן:    https://boti.bot/SwRI2ygd785H', 'descId': '5226FF95474EDA7DF44DD47523DE3C6E', 'descTime': 1644590663, 'descOwner': '972523737233@c.us', 'restrict': True, 'announce': False, 'noFrequentlyForwarded': False, 'ephemeralDuration': 0, 'size': 172, 'support': False, 'suspended': False, 'terminated': False, 'uniqueShortNameMap': {}, 'isParentGroup': False, 'defaultSubgroup': False, 'lastActivityTimestamp': 0, 'lastSeenActivityTimestamp': 0, 'incognito': False, 'participants': [{'id': '972523737233@c.us', 'isAdmin': True, 'isSuperAdmin': True}, {'id': '97249529911@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502036117@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502044103@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502272246@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502313231@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502740111@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502818065@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502885511@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972503322589@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972503531930@c.us', 'isAdmin': ...
#
#
#
#
# ({'ts': 1662040661527, 'sessionId': 'session', 'id': '612d0569-9c18-4655-866f-a06c28569fdd', 'event': 'onMessage', 'data': {'id': 'false_120363023352246358@g.us_1A42EA78BE581585A8B67324672740D1_972509500753@c.us', 'body': '', 'type': 'ciphertext', 't': 1662040661, 'notifyName': 'sigalsason1234', 'from': '120363023352246358@g.us', 'to': '972547932000@c.us', 'author': '972509500753@c.us', 'self': 'in', 'ack': 1, 'isNewMsg': True, 'star': False, 'kicNotified': False, 'recvFresh': True, 'isFromTemplate': False, 'pollInvalidated': False, 'broadcast': False, 'quotedMsg': None, 'mentionedJidList': [], 'isVcardOverMmsDocument': False, 'isForwarded': False, 'labels': [], 'hasReaction': False, 'productHeaderImageRejected': False, 'lastPlaybackProgress': 0, 'isDynamicReplyButtonsMsg': False, 'isMdHistoryMsg': False, 'requiresDirectConnection': False, 'pttForwardedFeaturesEnabled': True, 'fromMe': False, 'mId': '1A42EA78BE581585A8B67324672740D1', 'sender': {'id': '972509500753@c.us', 'type': 'in', 'formattedName': '+972 50-950-0753', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': True, 'isWAContact': True, 'profilePicThumbObj': {}, 'msgs': None}, 'timestamp': 1662040661, 'isGroupMsg': True, 'isMedia': False, 'isNotification': False, 'isPSA': False, 'chat': {'id': '120363023352246358@g.us', 'lastReceivedKey': {'fromMe': False, 'remote': '120363023352246358@g.us', 'id': '3EB0D76D7B4AC09F9CCC', 'participant': '972509500753@c.us', '_serialized': 'false_120363023352246358@g.us_3EB0D76D7B4AC09F9CCC_972509500753@c.us'}, 't': 1662039548, 'unreadCount': 1401, 'archive': True, 'isReadOnly': False, 'isAnnounceGrpRestrict': False, 'muteExpiration': 0, 'name': 'בוטי - עזרה,תמיכה,קהילה82', 'notSpam': True, 'ephemeralDuration': 0, 'unreadMentionsOfMe': [], 'unreadMentionCount': 0, 'hasUnreadMention': False, 'archiveAtMentionViewedInDrawer': False, 'hasChatBeenOpened': False, 'tcToken': None, 'tcTokenTimestamp': None, 'endOfHistoryTransferType': 2, 'pendingInitialLoading': False, 'msgs': None, 'kind': 'group', 'canSend': True, 'isGroup': True, 'formattedTitle': 'בוטי - עזרה,תמיכה,קהילה82', 'contact': {'id': '120363023352246358@g.us', 'name': 'בוטי - עזרה,תמיכה,קהילה82', 'type': 'in', 'formattedName': 'בוטי - עזרה,תמיכה,קהילה82', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': False, 'isWAContact': False, 'profilePicThumbObj': {'id': '120363023352246358@g.us', 'img': None, 'imgFull': None}, 'msgs': None}, 'groupMetadata': {'id': '120363023352246358@g.us', 'creation': 1644362711, 'owner': '972523737233@c.us', 'subject': 'בוטי - עזרה,תמיכה,קהילה82', 'subjectTime': 1644362711, 'desc': 'הקבוצה סגורה בשבתות תפתח אחרי שבת. \nרוצים לדעת מה קרה לבוטי?\nאיך אפשר להשתמש עכשיו?\nולמה זה קשור לפייסבוק?\nקראו כאן:    https://boti.bot/SwRI2ygd785H', 'descId': '5226FF95474EDA7DF44DD47523DE3C6E', 'descTime': 1644590663, 'descOwner': '972523737233@c.us', 'restrict': True, 'announce': False, 'noFrequentlyForwarded': False, 'ephemeralDuration': 0, 'size': 172, 'support': False, 'suspended': False, 'terminated': False, 'uniqueShortNameMap': {}, 'isParentGroup': False, 'defaultSubgroup': False, 'lastActivityTimestamp': 0, 'lastSeenActivityTimestamp': 0, 'incognito': False, 'participants': [{'id': '972523737233@c.us', 'isAdmin': True, 'isSuperAdmin': True}, {'id': '97249529911@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502036117@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502044103@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502272246@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502313231@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502740111@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502818065@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502885511@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972503322589@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972503531930@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'i ...
# !!!!INCOMING!!!! None
#  ::: INCOMING WHATSAPP MESSAGE ::: ({'ts': 1662040665635, 'sessionId': 'session', 'id': '38c42dd1-a65e-4d58-8c4b-8124a92f44c5', 'event': 'onMessage', 'data': {'id': 'false_120363023352246358@g.us_1A42EA78BE581585A8B67324672740D1_972509500753@c.us', 'body': 'היי, איך מבקשים תזכורת לסוף חודש לדוגמא', 'type': 'chat', 't': 1662040661, 'notifyName': 'sigalsason1234', 'from': '120363023352246358@g.us', 'to': '972547932000@c.us', 'author': '972509500753@c.us', 'self': 'in', 'ack': 1, 'isNewMsg': True, 'star': False, 'kicNotified': False, 'recvFresh': True, 'isFromTemplate': False, 'pollInvalidated': False, 'broadcast': False, 'quotedMsg': None, 'mentionedJidList': [], 'isVcardOverMmsDocument': False, 'isForwarded': False, 'labels': [], 'hasReaction': False, 'productHeaderImageRejected': False, 'lastPlaybackProgress': 0, 'isDynamicReplyButtonsMsg': False, 'isMdHistoryMsg': False, 'requiresDirectConnection': False, 'pttForwardedFeaturesEnabled': True, 'fromMe': False, 'mId': '1A42EA78BE581585A8B67324672740D1', 'sender': {'id': '972509500753@c.us', 'pushname': 'sigalsason1234', 'type': 'in', 'formattedName': '+972 50-950-0753', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': True, 'isWAContact': True, 'profilePicThumbObj': {}, 'msgs': None}, 'timestamp': 1662040661, 'content': 'היי, איך מבקשים תזכורת לסוף חודש לדוגמא', 'isGroupMsg': True, 'isMedia': False, 'isNotification': False, 'isPSA': False, 'chat': {'id': '120363023352246358@g.us', 'lastReceivedKey': {'fromMe': False, 'remote': '120363023352246358@g.us', 'id': '1A42EA78BE581585A8B67324672740D1', 'participant': '972509500753@c.us', '_serialized': 'false_120363023352246358@g.us_1A42EA78BE581585A8B67324672740D1_972509500753@c.us'}, 't': 1662040661, 'unreadCount': 1402, 'archive': True, 'isReadOnly': False, 'isAnnounceGrpRestrict': False, 'muteExpiration': 0, 'name': 'בוטי - עזרה,תמיכה,קהילה82', 'notSpam': True, 'ephemeralDuration': 0, 'unreadMentionsOfMe': [], 'unreadMentionCount': 0, 'hasUnreadMention': False, 'archiveAtMentionViewedInDrawer': False, 'hasChatBeenOpened': False, 'tcToken': None, 'tcTokenTimestamp': None, 'endOfHistoryTransferType': 2, 'pendingInitialLoading': False, 'msgs': None, 'kind': 'group', 'canSend': True, 'isGroup': True, 'formattedTitle': 'בוטי - עזרה,תמיכה,קהילה82', 'contact': {'id': '120363023352246358@g.us', 'name': 'בוטי - עזרה,תמיכה,קהילה82', 'type': 'in', 'formattedName': 'בוטי - עזרה,תמיכה,קהילה82', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': False, 'isWAContact': False, 'profilePicThumbObj': {'id': '120363023352246358@g.us', 'img': None, 'imgFull': None}, 'msgs': None}, 'groupMetadata': {'id': '120363023352246358@g.us', 'creation': 1644362711, 'owner': '972523737233@c.us', 'subject': 'בוטי - עזרה,תמיכה,קהילה82', 'subjectTime': 1644362711, 'desc': 'הקבוצה סגורה בשבתות תפתח אחרי שבת. \nרוצים לדעת מה קרה לבוטי?\nאיך אפשר להשתמש עכשיו?\nולמה זה קשור לפייסבוק?\nקראו כאן:    https://boti.bot/SwRI2ygd785H', 'descId': '5226FF95474EDA7DF44DD47523DE3C6E', 'descTime': 1644590663, 'descOwner': '972523737233@c.us', 'restrict': True, 'announce': False, 'noFrequentlyForwarded': False, 'ephemeralDuration': 0, 'size': 172, 'support': False, 'suspended': False, 'terminated': False, 'uniqueShortNameMap': {}, 'isParentGroup': False, 'defaultSubgroup': False, 'lastActivityTimestamp': 0, 'lastSeenActivityTimestamp': 0, 'incognito': False, 'participants': [{'id': '972523737233@c.us', 'isAdmin': True, 'isSuperAdmin': True}, {'id': '97249529911@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502036117@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502044103@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502272246@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502313231@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502740111@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502818065@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502885511@c.us', 'isAdmin' ...
#
#
#
#
# ({'ts': 1662040665635, 'sessionId': 'session', 'id': '38c42dd1-a65e-4d58-8c4b-8124a92f44c5', 'event': 'onMessage', 'data': {'id': 'false_120363023352246358@g.us_1A42EA78BE581585A8B67324672740D1_972509500753@c.us', 'body': 'היי, איך מבקשים תזכורת לסוף חודש לדוגמא', 'type': 'chat', 't': 1662040661, 'notifyName': 'sigalsason1234', 'from': '120363023352246358@g.us', 'to': '972547932000@c.us', 'author': '972509500753@c.us', 'self': 'in', 'ack': 1, 'isNewMsg': True, 'star': False, 'kicNotified': False, 'recvFresh': True, 'isFromTemplate': False, 'pollInvalidated': False, 'broadcast': False, 'quotedMsg': None, 'mentionedJidList': [], 'isVcardOverMmsDocument': False, 'isForwarded': False, 'labels': [], 'hasReaction': False, 'productHeaderImageRejected': False, 'lastPlaybackProgress': 0, 'isDynamicReplyButtonsMsg': False, 'isMdHistoryMsg': False, 'requiresDirectConnection': False, 'pttForwardedFeaturesEnabled': True, 'fromMe': False, 'mId': '1A42EA78BE581585A8B67324672740D1', 'sender': {'id': '972509500753@c.us', 'pushname': 'sigalsason1234', 'type': 'in', 'formattedName': '+972 50-950-0753', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': True, 'isWAContact': True, 'profilePicThumbObj': {}, 'msgs': None}, 'timestamp': 1662040661, 'content': 'היי, איך מבקשים תזכורת לסוף חודש לדוגמא', 'isGroupMsg': True, 'isMedia': False, 'isNotification': False, 'isPSA': False, 'chat': {'id': '120363023352246358@g.us', 'lastReceivedKey': {'fromMe': False, 'remote': '120363023352246358@g.us', 'id': '1A42EA78BE581585A8B67324672740D1', 'participant': '972509500753@c.us', '_serialized': 'false_120363023352246358@g.us_1A42EA78BE581585A8B67324672740D1_972509500753@c.us'}, 't': 1662040661, 'unreadCount': 1402, 'archive': True, 'isReadOnly': False, 'isAnnounceGrpRestrict': False, 'muteExpiration': 0, 'name': 'בוטי - עזרה,תמיכה,קהילה82', 'notSpam': True, 'ephemeralDuration': 0, 'unreadMentionsOfMe': [], 'unreadMentionCount': 0, 'hasUnreadMention': False, 'archiveAtMentionViewedInDrawer': False, 'hasChatBeenOpened': False, 'tcToken': None, 'tcTokenTimestamp': None, 'endOfHistoryTransferType': 2, 'pendingInitialLoading': False, 'msgs': None, 'kind': 'group', 'canSend': True, 'isGroup': True, 'formattedTitle': 'בוטי - עזרה,תמיכה,קהילה82', 'contact': {'id': '120363023352246358@g.us', 'name': 'בוטי - עזרה,תמיכה,קהילה82', 'type': 'in', 'formattedName': 'בוטי - עזרה,תמיכה,קהילה82', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': False, 'isWAContact': False, 'profilePicThumbObj': {'id': '120363023352246358@g.us', 'img': None, 'imgFull': None}, 'msgs': None}, 'groupMetadata': {'id': '120363023352246358@g.us', 'creation': 1644362711, 'owner': '972523737233@c.us', 'subject': 'בוטי - עזרה,תמיכה,קהילה82', 'subjectTime': 1644362711, 'desc': 'הקבוצה סגורה בשבתות תפתח אחרי שבת. \nרוצים לדעת מה קרה לבוטי?\nאיך אפשר להשתמש עכשיו?\nולמה זה קשור לפייסבוק?\nקראו כאן:    https://boti.bot/SwRI2ygd785H', 'descId': '5226FF95474EDA7DF44DD47523DE3C6E', 'descTime': 1644590663, 'descOwner': '972523737233@c.us', 'restrict': True, 'announce': False, 'noFrequentlyForwarded': False, 'ephemeralDuration': 0, 'size': 172, 'support': False, 'suspended': False, 'terminated': False, 'uniqueShortNameMap': {}, 'isParentGroup': False, 'defaultSubgroup': False, 'lastActivityTimestamp': 0, 'lastSeenActivityTimestamp': 0, 'incognito': False, 'participants': [{'id': '972523737233@c.us', 'isAdmin': True, 'isSuperAdmin': True}, {'id': '97249529911@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502036117@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502044103@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502272246@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502313231@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502740111@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502818065@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502885511@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {' ...
# !!!!INCOMING!!!! None
#  ::: INCOMING WHATSAPP MESSAGE ::: ({'ts': 1662044700028, 'sessionId': 'session', 'id': 'a8620b04-1ab8-42eb-ac5e-d9b264327d72', 'event': 'onMessage', 'data': {'id': 'false_972542175151-1589050254@g.us_5FEF2FC21BC60155C3C2408108729D9A_972545801895@c.us', 'body': 'מסאבלט יחידה מהממת בתל יצחק מה11.09 עד ה20.10 אם מישהו.י צריכים/מכירים מוזמנים לדבר איתי :)', 'type': 'chat', 't': 1662044094, 'notifyName': 'Tomer', 'from': '972542175151-1589050254@g.us', 'to': '972547932000@c.us', 'author': '972545801895@c.us', 'self': 'in', 'ack': 1, 'isNewMsg': True, 'star': False, 'kicNotified': False, 'recvFresh': True, 'isFromTemplate': False, 'pollInvalidated': False, 'broadcast': False, 'quotedMsg': None, 'mentionedJidList': [], 'isVcardOverMmsDocument': False, 'isForwarded': False, 'labels': [], 'hasReaction': False, 'productHeaderImageRejected': False, 'lastPlaybackProgress': 0, 'isDynamicReplyButtonsMsg': False, 'isMdHistoryMsg': False, 'requiresDirectConnection': False, 'pttForwardedFeaturesEnabled': True, 'fromMe': False, 'mId': '5FEF2FC21BC60155C3C2408108729D9A', 'sender': {'id': '972545801895@c.us', 'pushname': 'Tomer', 'type': 'in', 'isContactSyncCompleted': 1, 'formattedName': '+972 54-580-1895', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': True, 'isWAContact': True, 'profilePicThumbObj': {}, 'msgs': None}, 'timestamp': 1662044094, 'content': 'מסאבלט יחידה מהממת בתל יצחק מה11.09 עד ה20.10 אם מישהו.י צריכים/מכירים מוזמנים לדבר איתי :)', 'isGroupMsg': True, 'isMedia': False, 'isNotification': False, 'isPSA': False, 'chat': {'id': '972542175151-1589050254@g.us', 'lastReceivedKey': {'fromMe': False, 'remote': '972542175151-1589050254@g.us', 'id': '7C4BB248458EEA6C7F01C1720344585E', 'participant': '972504664141@c.us', '_serialized': 'false_972542175151-1589050254@g.us_7C4BB248458EEA6C7F01C1720344585E_972504664141@c.us'}, 't': 1662035959, 'unreadCount': 597, 'archive': True, 'isReadOnly': False, 'isAnnounceGrpRestrict': False, 'muteExpiration': -1, 'name': 'קהילת ג׳אמים ואהבה 09', 'notSpam': True, 'ephemeralDuration': 0, 'unreadMentionsOfMe': [], 'unreadMentionCount': 0, 'hasUnreadMention': False, 'archiveAtMentionViewedInDrawer': False, 'hasChatBeenOpened': False, 'tcToken': None, 'tcTokenTimestamp': None, 'endOfHistoryTransferType': 2, 'pendingInitialLoading': False, 'msgs': None, 'kind': 'group', 'canSend': True, 'isGroup': True, 'formattedTitle': 'קהילת ג׳אמים ואהבה 09', 'contact': {'id': '972542175151-1589050254@g.us', 'name': 'קהילת ג׳אמים ואהבה 09', 'type': 'in', 'formattedName': 'קהילת ג׳אמים ואהבה 09', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': False, 'isWAContact': False, 'profilePicThumbObj': {'id': '972542175151-1589050254@g.us', 'img': None, 'imgFull': None}, 'msgs': None}, 'groupMetadata': {'id': '972542175151-1589050254@g.us', 'creation': 1589050254, 'owner': '972542175151@c.us', 'subject': 'קהילת ג׳אמים ואהבה 09', 'subjectTime': 1591520800, 'desc': 'קישור לצירוף:\nhttps://chat.whatsapp.com/GY4tBCSZqDP0jDJsFKXI0Y', 'descId': '1614674978-23', 'descTime': 1614675750, 'descOwner': '972503521110@c.us', 'restrict': True, 'announce': False, 'noFrequentlyForwarded': False, 'ephemeralDuration': 0, 'size': 281, 'support': False, 'suspended': False, 'terminated': False, 'uniqueShortNameMap': {}, 'isParentGroup': False, 'defaultSubgroup': False, 'lastActivityTimestamp': 0, 'lastSeenActivityTimestamp': 0, 'incognito': False, 'participants': [{'id': '972523488357@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972523330325@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972526621788@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972586938988@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972508895757@c.us', 'isAdmin': True, 'isSuperAdmin': False}, {'id': '972524765034@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972547667537@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972504554044@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '9 ...
#
#
#
#
# ({'ts': 1662044700028, 'sessionId': 'session', 'id': 'a8620b04-1ab8-42eb-ac5e-d9b264327d72', 'event': 'onMessage', 'data': {'id': 'false_972542175151-1589050254@g.us_5FEF2FC21BC60155C3C2408108729D9A_972545801895@c.us', 'body': 'מסאבלט יחידה מהממת בתל יצחק מה11.09 עד ה20.10 אם מישהו.י צריכים/מכירים מוזמנים לדבר איתי :)', 'type': 'chat', 't': 1662044094, 'notifyName': 'Tomer', 'from': '972542175151-1589050254@g.us', 'to': '972547932000@c.us', 'author': '972545801895@c.us', 'self': 'in', 'ack': 1, 'isNewMsg': True, 'star': False, 'kicNotified': False, 'recvFresh': True, 'isFromTemplate': False, 'pollInvalidated': False, 'broadcast': False, 'quotedMsg': None, 'mentionedJidList': [], 'isVcardOverMmsDocument': False, 'isForwarded': False, 'labels': [], 'hasReaction': False, 'productHeaderImageRejected': False, 'lastPlaybackProgress': 0, 'isDynamicReplyButtonsMsg': False, 'isMdHistoryMsg': False, 'requiresDirectConnection': False, 'pttForwardedFeaturesEnabled': True, 'fromMe': False, 'mId': '5FEF2FC21BC60155C3C2408108729D9A', 'sender': {'id': '972545801895@c.us', 'pushname': 'Tomer', 'type': 'in', 'isContactSyncCompleted': 1, 'formattedName': '+972 54-580-1895', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': True, 'isWAContact': True, 'profilePicThumbObj': {}, 'msgs': None}, 'timestamp': 1662044094, 'content': 'מסאבלט יחידה מהממת בתל יצחק מה11.09 עד ה20.10 אם מישהו.י צריכים/מכירים מוזמנים לדבר איתי :)', 'isGroupMsg': True, 'isMedia': False, 'isNotification': False, 'isPSA': False, 'chat': {'id': '972542175151-1589050254@g.us', 'lastReceivedKey': {'fromMe': False, 'remote': '972542175151-1589050254@g.us', 'id': '7C4BB248458EEA6C7F01C1720344585E', 'participant': '972504664141@c.us', '_serialized': 'false_972542175151-1589050254@g.us_7C4BB248458EEA6C7F01C1720344585E_972504664141@c.us'}, 't': 1662035959, 'unreadCount': 597, 'archive': True, 'isReadOnly': False, 'isAnnounceGrpRestrict': False, 'muteExpiration': -1, 'name': 'קהילת ג׳אמים ואהבה 09', 'notSpam': True, 'ephemeralDuration': 0, 'unreadMentionsOfMe': [], 'unreadMentionCount': 0, 'hasUnreadMention': False, 'archiveAtMentionViewedInDrawer': False, 'hasChatBeenOpened': False, 'tcToken': None, 'tcTokenTimestamp': None, 'endOfHistoryTransferType': 2, 'pendingInitialLoading': False, 'msgs': None, 'kind': 'group', 'canSend': True, 'isGroup': True, 'formattedTitle': 'קהילת ג׳אמים ואהבה 09', 'contact': {'id': '972542175151-1589050254@g.us', 'name': 'קהילת ג׳אמים ואהבה 09', 'type': 'in', 'formattedName': 'קהילת ג׳אמים ואהבה 09', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': False, 'isWAContact': False, 'profilePicThumbObj': {'id': '972542175151-1589050254@g.us', 'img': None, 'imgFull': None}, 'msgs': None}, 'groupMetadata': {'id': '972542175151-1589050254@g.us', 'creation': 1589050254, 'owner': '972542175151@c.us', 'subject': 'קהילת ג׳אמים ואהבה 09', 'subjectTime': 1591520800, 'desc': 'קישור לצירוף:\nhttps://chat.whatsapp.com/GY4tBCSZqDP0jDJsFKXI0Y', 'descId': '1614674978-23', 'descTime': 1614675750, 'descOwner': '972503521110@c.us', 'restrict': True, 'announce': False, 'noFrequentlyForwarded': False, 'ephemeralDuration': 0, 'size': 281, 'support': False, 'suspended': False, 'terminated': False, 'uniqueShortNameMap': {}, 'isParentGroup': False, 'defaultSubgroup': False, 'lastActivityTimestamp': 0, 'lastSeenActivityTimestamp': 0, 'incognito': False, 'participants': [{'id': '972523488357@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972523330325@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972526621788@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972586938988@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972508895757@c.us', 'isAdmin': True, 'isSuperAdmin': False}, {'id': '972524765034@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972547667537@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972504554044@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972528376300@c.us', 'isAdmin': False ...
# !!!!INCOMING!!!! None
#  ::: INCOMING WHATSAPP MESSAGE ::: ({'ts': 1662044700208, 'sessionId': 'session', 'id': '9305bba9-8ac5-46cb-8ecb-699338cdc60e', 'event': 'onMessage', 'data': {'id': 'false_972542175151-1589050254@g.us_A80BBE9D81118E5097CA3B044600454E_972502033326@c.us', 'body': 'אבל מתי זה?😅😅', 'type': 'chat', 't': 1662044223, 'notifyName': 'Mor', 'from': '972542175151-1589050254@g.us', 'to': '972547932000@c.us', 'author': '972502033326@c.us', 'self': 'in', 'ack': 1, 'isNewMsg': True, 'star': False, 'kicNotified': False, 'recvFresh': True, 'isFromTemplate': False, 'thumbnail': '', 'richPreviewType': 0, 'pollInvalidated': False, 'broadcast': False, 'quotedMsg': {'id': 'false_972542175151-1589050254@g.us_3A6ED3B65EEFEA8C064E_972534310575@c.us', 'body': 'הי הי חברים של הפופ אפ! 💚✌️\nרגע לפני שיוצאים לפגרה..🍹🍸🍹 \nאנחנו עושים מ-ס-י-ב-ה מטריפה!!!\n🥳🤩🥳 \nכולם מוזמנים להגיע ולהביא לרחבה.. 🎚️🤟 מלא כיף ומלא אהבה ❤️ \nמיקום מדוייק ישלח בקבוצה:\n(תהיה גם פיצה אל דאגה.. 🍕)\n\nhttps://chat.whatsapp.com/EiO4qFewaAuDNBYPKHMOni\n\nתשלום בפייבוקס או בביט יתקבל בברכה 😊\n 30 שח צנועים יעשו את העבודה 👇\n\nהשימוש ב-PayBox חינם!\nמחכים לך בקבוצת "Pop up Party",\nלחיצה להצטרפות לקבוצה: \n\nhttps://payboxapp.page.link/mv3Xmx6YXD69vgAq6', 'type': 'chat', 'subtype': 'url', 'from': '972542175151-1589050254@g.us', 'to': '972547932000@c.us', 'author': '972534310575@c.us', 'self': 'in', 'star': False, 'kicNotified': False, 'isFromTemplate': False, 'matchedText': 'https://chat.whatsapp.com/EiO4qFewaAuDNBYPKHMOni', 'thumbnail': '...', 'richPreviewType': 0, 'title': 'פופ-אפ בר רשפון', 'description': 'הזמנה לקבוצת WhatsApp', 'pollInvalidated': False, 'quotedMsg': None, 'mentionedJidList': [], 'isVcardOverMmsDocument': False, 'isForwarded': False, 'labels': [], 'hasReaction': False, 'inviteGrpType': 'DEFAULT', 'productHeaderImageRejected': False, 'lastPlaybackProgress': 0, 'isDynamicReplyButtonsMsg': False, 'isMdHistoryMsg': False, 'requiresDirectConnection': None, 'pttForwardedFeaturesEnabled': True, 'fromMe': False, 'mId': '3A6ED3B65EEFEA8C064E', 'sender': {'id': '972534310575@c.us', 'pushname': 'Yul 🌞', 'type': 'in', 'isContactSyncCompleted': 1, 'formattedName': '+972 53-431-0575', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': True, 'isWAContact': True, 'profilePicThumbObj': {}, 'msgs': None}, 'content': 'הי הי חברים של הפופ אפ! 💚✌️\nרגע לפני שיוצאים לפגרה..🍹🍸🍹 \nאנחנו עושים מ-ס-י-ב-ה מטריפה!!!\n🥳🤩🥳 \nכולם מוזמנים להגיע ולהביא לרחבה.. 🎚️🤟 מלא כיף ומלא אהבה ❤️ \nמיקום מדוייק ישלח בקבוצה:\n(תהיה גם פיצה אל דאגה.. 🍕)\n\nhttps://chat.whatsapp.com/EiO4qFewaAuDNBYPKHMOni\n\nתשלום בפייבוקס או בביט יתקבל בברכה 😊\n 30 שח צנועים יעשו את העבודה 👇\n\nהשימוש ב-PayBox חינם!\nמחכים לך בקבוצת "Pop up Party",\nלחיצה להצטרפות לקבוצה: \n\nhttps://payboxapp.page.link/mv3Xmx6YXD69vgAq6', 'isGroupMsg': True, 'isMedia': False, 'isNotification': False, 'isPSA': False, 'chat': {'id': '972542175151-1589050254@g.us', 'lastReceivedKey': {'fromMe': False, 'remote': '972542175151-1589050254@g.us', 'id': 'A80BBE9D81118E5097CA3B044600454E', 'participant': '972502033326@c.us', '_serialized': 'false_972542175151-1589050254@g.us_A80BBE9D81118E5097CA3B044600454E_972502033326@c.us'}, 't': 1662044094, 'unreadCount': 598, 'archive': True, 'isReadOnly': False, 'isAnnounceGrpRestrict': False, 'muteExpiration': -1, 'name': 'קהילת ג׳אמים ואהבה 09', 'notSpam': True, 'ephemeralDuration': 0, 'unreadMentionsOfMe': [], 'unreadMentionCount': 0, 'hasUnreadMention': False, 'archiveAtMentionViewedInDrawer': False, 'hasChatBeenOpened': False, 'tcToken': None, 'tcTokenTimestamp': None, 'endOfHistoryTransferType': 2, 'pendingInitialLoading': False, 'msgs': None, 'kind': 'group', 'canSend': True, 'isGroup': True, 'formattedTitle': 'קהילת ג׳אמים ואהבה 09', 'contact': {'id': '972542175151-1589050254@g.us', 'name': 'קהילת ג׳אמים ואהבה 09', 'type': 'in', 'formattedName': 'קהילת ג׳אמים ואהבה 09', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': False, 'isWAContact': False, 'profilePicThumbObj': {'id': '97 ...
#
#
#
#
# ...
#
#
#
#
# ({'ts': 1662046052244, 'sessionId': 'session', 'id': 'acd24c49-5221-467a-8cae-649fa04accf8', 'event': 'onMessage', 'data': {'id': 'false_972542175151-1589050254@g.us_BA23BCFAFE435087D2392D84D2684C4B_972504554044@c.us', 'body': '...', 'type': 'image', 't': 1662046051, 'notifyName': 'טל אישה 🌺', 'from': '972542175151-1589050254@g.us', 'to': '972547932000@c.us', 'author': '972504554044@c.us', 'self': 'in', 'ack': 1, 'isNewMsg': True, 'star': False, 'kicNotified': False, 'recvFresh': True, 'caption': "שלום קהילה פלאית 09🌻\nוהמעשנים היקרים 💕\n\nכל מי שמעוניין לעשות שלום עם הטבק,\nולהבין איך להשתחרר מהפחד להפסיק לעשן ~\n\nיצרתי הדרכה מלאת ערך, שתהיה ללא עלות, בה אנחנו הולכים ללמוד ולהבין ביחד איך אפשר לשחרר את הסיפורים, את החששות והפחד מלהפסיק לעשן.\n\nמהסיפור שלי ומהדרך שעברתי אני יכולה להגיד שזה ממש אפשרי וזו אחת המתנות הגדולות לחיים 🙌🏼🌟\n\nמי שיגיע, תתכוננו שיפלו לכם אסימונים חשובים \U0001fa99✨\n\nלהדרכה קראתי\n'איך להשתחרר מהפחד להפסיק לעשן' 💛\n\nהיא תתקיים ביום ב' ה12.9\nבשעה 20:00 בערב\nבשידור חי בזום, וללא עלות.\n(לא תהיה הקלטה)\n\nלפרטים נוספים ולהרשמה אני מצרפת קישור להזמנה\n\nhttps://belev.co.il/breaking_up_from_tobacco/\n\nאם אתם או אנשים שאתם מכירים נראים לכם מתאימים, \nומוכנים לשלב של לעשות שלום עם הריאות 🦋\nמוזמנים להצטרף להדרכה באהבה, ולהרשם בתחתית הדף 💗\nאפשר לשתף את הקישור בשמחה.\n\nלכל שאלה אני כאן 🙏🏼\nנתראה בקרוב,\nטל 💧", 'interactiveAnnotations': [], 'clientUrl': 'https://mmg.whatsapp.net/d/f/AqsHiOcO9-khK_tMzs9xMCG1jaNn2CsAPkWR0czroCvm.enc', 'deprecatedMms3Url': 'https://mmg.whatsapp.net/d/f/AqsHiOcO9-khK_tMzs9xMCG1jaNn2CsAPkWR0czroCvm.enc', 'directPath': '/v/t62.7118-24/35200686_607960754191268_4285289207081248715_n.enc?ccb=11-4&oh=01_AVxQWRD9TivaZqcfM9Lh54tukYpPdUvTFbPfd4TembsZvw&oe=6336BF29', 'mimetype': 'image/jpeg', 'filehash': '5rLvUsFK+HJ0LPxMdEyWsQKC37GS2VzEShAAFrsWWN4=', 'encFilehash': 'HAkIxrVJHhQpCVYYrSJTDgumw9OURFSyEVDFfNPqOGA=', 'size': 183885, 'mediaKey': 'N5QGcW/Q2A/g3XeSRNmaSx0xWQf0DMmPSYdypLwYgGQ=', 'mediaKeyTimestamp': 1662044483, 'isViewOnce': False, 'width': 1600, 'height': 800, 'staticUrl': '', 'scanLengths': [], 'isFromTemplate': False, 'pollInvalidated': False, 'broadcast': False, 'quotedMsg': None, 'mentionedJidList': [], 'isVcardOverMmsDocument': False, 'isForwarded': False, 'labels': [], 'hasReaction': False, 'productHeaderImageRejected': False, 'lastPlaybackProgress': 0, 'isDynamicReplyButtonsMsg': False, 'isMdHistoryMsg': False, 'requiresDirectConnection': False, 'pttForwardedFeaturesEnabled': True, 'fromMe': False, 'mId': 'BA23BCFAFE435087D2392D84D2684C4B', 'sender': {'id': '972504554044@c.us', 'name': 'טל גיטרה ג׳אמ', 'shortName': 'טל', 'pushname': 'טל אישה 🌺', 'type': 'in', 'isContactSyncCompleted': 1, 'formattedName': 'טל גיטרה ג׳אמ', 'isMe': False, 'isMyContact': True, 'isPSA': False, 'isUser': True, 'isWAContact': True, 'profilePicThumbObj': {}, 'msgs': None}, 'timestamp': 1662046051, 'content': '...', 'isGroupMsg': True, 'isMedia': True, 'isNotification': False, 'isPSA': False, 'chat': {'id': '972542175151-1589050254@g.us', 'lastReceivedKey': {'fromMe': False, 'remote': '972542175151-1589050254@g.us', 'id': '3EB00CBEEE5FC79B1980', 'participant': '972546944421@c.us', '_serialized': 'false_972542175151-1589050254@g.us_3EB00CBEEE5FC79B1980_972546944421@c.us'}, 't': 1662044374, 'unreadCount': 600, 'archive': True, 'isReadOnly': False, 'isAnnounceGrpRestrict': False, 'muteExpiration': -1, 'name': 'קהילת ג׳אמים ואהבה 09', 'notSpam': True, 'ephemeralDuration': 0, 'unreadMentionsOfMe': [], 'unreadMentionCount': 0, 'hasUnreadMention': False, 'archiveAtMentionViewedInDrawer': False, 'hasChatBeenOpened': False, 'tcToken': None, 'tcTokenTimestamp': None, 'endOfHistoryTransferType': 2, 'pendingInitialLoading': False, 'msgs': None, 'kind': 'group', 'canSend': True, 'isGroup': True, 'formattedTitle': 'קהילת ג׳אמים ואהבה 09', 'contact': {'id': '972542175151-1589050254@g.us', 'name': 'קהילת ג׳אמים ואהבה 09', 'type': 'in', 'formattedName': 'קהילת ג׳אמים ואהבה 09', 'isMe': False, 'isMyContact': F ...
# !!!!INCOMING!!!! None
#  ::: INCOMING WHATSAPP MESSAGE ::: ({'ts': 1662046293322, 'sessionId': 'session', 'id': 'aa6acf7d-ae82-40e3-a8b4-b72bb8b0265d', 'event': 'onMessage', 'data': {'id': 'false_120363023352246358@g.us_3EB06243FE7ABDAC0FBB_972527203451@c.us', 'body': "כתוב לבוטי 'תזכורת קבועה'", 'type': 'chat', 't': 1662046292, 'notifyName': 'רביבית', 'from': '120363023352246358@g.us', 'to': '972547932000@c.us', 'author': '972527203451@c.us', 'self': 'in', 'ack': 1, 'isNewMsg': True, 'star': False, 'kicNotified': False, 'recvFresh': True, 'isFromTemplate': False, 'thumbnail': '', 'pollInvalidated': False, 'broadcast': False, 'quotedMsg': {'id': 'false_120363023352246358@g.us_1A42EA78BE581585A8B67324672740D1_972509500753@c.us', 'body': 'היי, איך מבקשים תזכורת לסוף חודש לדוגמא', 'type': 'chat', 'from': '120363023352246358@g.us', 'to': '972547932000@c.us', 'author': '972509500753@c.us', 'self': 'in', 'star': False, 'kicNotified': False, 'isFromTemplate': False, 'pollInvalidated': False, 'quotedMsg': None, 'mentionedJidList': [], 'isVcardOverMmsDocument': False, 'isForwarded': False, 'labels': [], 'hasReaction': False, 'productHeaderImageRejected': False, 'lastPlaybackProgress': 0, 'isDynamicReplyButtonsMsg': False, 'isMdHistoryMsg': False, 'requiresDirectConnection': None, 'pttForwardedFeaturesEnabled': True, 'fromMe': False, 'mId': '1A42EA78BE581585A8B67324672740D1', 'sender': {'id': '972509500753@c.us', 'pushname': 'sigalsason1234', 'type': 'in', 'formattedName': '+972 50-950-0753', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': True, 'isWAContact': True, 'profilePicThumbObj': {}, 'msgs': None}, 'content': 'היי, איך מבקשים תזכורת לסוף חודש לדוגמא', 'isGroupMsg': True, 'isMedia': False, 'isNotification': False, 'isPSA': False, 'chat': {'id': '120363023352246358@g.us', 'lastReceivedKey': {'fromMe': False, 'remote': '120363023352246358@g.us', 'id': '3EB06243FE7ABDAC0FBB', 'participant': '972527203451@c.us', '_serialized': 'false_120363023352246358@g.us_3EB06243FE7ABDAC0FBB_972527203451@c.us'}, 't': 1662040661, 'unreadCount': 1402, 'archive': True, 'isReadOnly': False, 'isAnnounceGrpRestrict': False, 'muteExpiration': 0, 'name': 'בוטי - עזרה,תמיכה,קהילה82', 'notSpam': True, 'ephemeralDuration': 0, 'unreadMentionsOfMe': [], 'unreadMentionCount': 0, 'hasUnreadMention': False, 'archiveAtMentionViewedInDrawer': False, 'hasChatBeenOpened': False, 'tcToken': None, 'tcTokenTimestamp': None, 'endOfHistoryTransferType': 2, 'pendingInitialLoading': False, 'msgs': None, 'kind': 'group', 'canSend': True, 'isGroup': True, 'formattedTitle': 'בוטי - עזרה,תמיכה,קהילה82', 'contact': {'id': '120363023352246358@g.us', 'name': 'בוטי - עזרה,תמיכה,קהילה82', 'type': 'in', 'formattedName': 'בוטי - עזרה,תמיכה,קהילה82', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': False, 'isWAContact': False, 'profilePicThumbObj': {'id': '120363023352246358@g.us', 'img': None, 'imgFull': None}, 'msgs': None}, 'groupMetadata': {'id': '120363023352246358@g.us', 'creation': 1644362711, 'owner': '972523737233@c.us', 'subject': 'בוטי - עזרה,תמיכה,קהילה82', 'subjectTime': 1644362711, 'desc': 'הקבוצה סגורה בשבתות תפתח אחרי שבת. \nרוצים לדעת מה קרה לבוטי?\nאיך אפשר להשתמש עכשיו?\nולמה זה קשור לפייסבוק?\nקראו כאן:    https://boti.bot/SwRI2ygd785H', 'descId': '5226FF95474EDA7DF44DD47523DE3C6E', 'descTime': 1644590663, 'descOwner': '972523737233@c.us', 'restrict': True, 'announce': False, 'noFrequentlyForwarded': False, 'ephemeralDuration': 0, 'size': 172, 'support': False, 'suspended': False, 'terminated': False, 'uniqueShortNameMap': {}, 'isParentGroup': False, 'defaultSubgroup': False, 'lastActivityTimestamp': 0, 'lastSeenActivityTimestamp': 0, 'incognito': False, 'participants': [{'id': '972523737233@c.us', 'isAdmin': True, 'isSuperAdmin': True}, {'id': '97249529911@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502036117@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502044103@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '9725022722 ...
#
#
#
#
# ({'ts': 1662046293322, 'sessionId': 'session', 'id': 'aa6acf7d-ae82-40e3-a8b4-b72bb8b0265d', 'event': 'onMessage', 'data': {'id': 'false_120363023352246358@g.us_3EB06243FE7ABDAC0FBB_972527203451@c.us', 'body': "כתוב לבוטי 'תזכורת קבועה'", 'type': 'chat', 't': 1662046292, 'notifyName': 'רביבית', 'from': '120363023352246358@g.us', 'to': '972547932000@c.us', 'author': '972527203451@c.us', 'self': 'in', 'ack': 1, 'isNewMsg': True, 'star': False, 'kicNotified': False, 'recvFresh': True, 'isFromTemplate': False, 'thumbnail': '', 'pollInvalidated': False, 'broadcast': False, 'quotedMsg': {'id': 'false_120363023352246358@g.us_1A42EA78BE581585A8B67324672740D1_972509500753@c.us', 'body': 'היי, איך מבקשים תזכורת לסוף חודש לדוגמא', 'type': 'chat', 'from': '120363023352246358@g.us', 'to': '972547932000@c.us', 'author': '972509500753@c.us', 'self': 'in', 'star': False, 'kicNotified': False, 'isFromTemplate': False, 'pollInvalidated': False, 'quotedMsg': None, 'mentionedJidList': [], 'isVcardOverMmsDocument': False, 'isForwarded': False, 'labels': [], 'hasReaction': False, 'productHeaderImageRejected': False, 'lastPlaybackProgress': 0, 'isDynamicReplyButtonsMsg': False, 'isMdHistoryMsg': False, 'requiresDirectConnection': None, 'pttForwardedFeaturesEnabled': True, 'fromMe': False, 'mId': '1A42EA78BE581585A8B67324672740D1', 'sender': {'id': '972509500753@c.us', 'pushname': 'sigalsason1234', 'type': 'in', 'formattedName': '+972 50-950-0753', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': True, 'isWAContact': True, 'profilePicThumbObj': {}, 'msgs': None}, 'content': 'היי, איך מבקשים תזכורת לסוף חודש לדוגמא', 'isGroupMsg': True, 'isMedia': False, 'isNotification': False, 'isPSA': False, 'chat': {'id': '120363023352246358@g.us', 'lastReceivedKey': {'fromMe': False, 'remote': '120363023352246358@g.us', 'id': '3EB06243FE7ABDAC0FBB', 'participant': '972527203451@c.us', '_serialized': 'false_120363023352246358@g.us_3EB06243FE7ABDAC0FBB_972527203451@c.us'}, 't': 1662040661, 'unreadCount': 1402, 'archive': True, 'isReadOnly': False, 'isAnnounceGrpRestrict': False, 'muteExpiration': 0, 'name': 'בוטי - עזרה,תמיכה,קהילה82', 'notSpam': True, 'ephemeralDuration': 0, 'unreadMentionsOfMe': [], 'unreadMentionCount': 0, 'hasUnreadMention': False, 'archiveAtMentionViewedInDrawer': False, 'hasChatBeenOpened': False, 'tcToken': None, 'tcTokenTimestamp': None, 'endOfHistoryTransferType': 2, 'pendingInitialLoading': False, 'msgs': None, 'kind': 'group', 'canSend': True, 'isGroup': True, 'formattedTitle': 'בוטי - עזרה,תמיכה,קהילה82', 'contact': {'id': '120363023352246358@g.us', 'name': 'בוטי - עזרה,תמיכה,קהילה82', 'type': 'in', 'formattedName': 'בוטי - עזרה,תמיכה,קהילה82', 'isMe': False, 'isMyContact': False, 'isPSA': False, 'isUser': False, 'isWAContact': False, 'profilePicThumbObj': {'id': '120363023352246358@g.us', 'img': None, 'imgFull': None}, 'msgs': None}, 'groupMetadata': {'id': '120363023352246358@g.us', 'creation': 1644362711, 'owner': '972523737233@c.us', 'subject': 'בוטי - עזרה,תמיכה,קהילה82', 'subjectTime': 1644362711, 'desc': 'הקבוצה סגורה בשבתות תפתח אחרי שבת. \nרוצים לדעת מה קרה לבוטי?\nאיך אפשר להשתמש עכשיו?\nולמה זה קשור לפייסבוק?\nקראו כאן:    https://boti.bot/SwRI2ygd785H', 'descId': '5226FF95474EDA7DF44DD47523DE3C6E', 'descTime': 1644590663, 'descOwner': '972523737233@c.us', 'restrict': True, 'announce': False, 'noFrequentlyForwarded': False, 'ephemeralDuration': 0, 'size': 172, 'support': False, 'suspended': False, 'terminated': False, 'uniqueShortNameMap': {}, 'isParentGroup': False, 'defaultSubgroup': False, 'lastActivityTimestamp': 0, 'lastSeenActivityTimestamp': 0, 'incognito': False, 'participants': [{'id': '972523737233@c.us', 'isAdmin': True, 'isSuperAdmin': True}, {'id': '97249529911@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502036117@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502044103@c.us', 'isAdmin': False, 'isSuperAdmin': False}, {'id': '972502272246@c.us', 'isAdmin': False, 'isSupe ...
# !!!!INCOMING!!!! None
